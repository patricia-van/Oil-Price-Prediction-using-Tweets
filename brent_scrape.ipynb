# %%
import os
import datetime as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader.data as web
from scipy import stats
import statsmodels.api as sm
import seaborn as sns

# %%
start = dt.datetime(2020, 1, 1)
end = dt.datetime.today().strftime('%Y-%m-%d')
brent_oil_price = web.DataReader('DCOILBRENTEU', 'fred', start, end)

# save the data
file_path = 'DCOILBRENTEU.csv'
brent_oil_price.to_csv(file_path)
brent_oil_price = pd.read_csv(file_path, index_col="DATE", parse_dates=True)

print(brent_oil_price.shape)
brent_oil_price
# Out:
# (1169, 1)
#             DCOILBRENTEU
# DATE
# 2020-01-01           NaN
# 2020-01-02         67.05
# 2020-01-03         69.08
# 2020-01-06         70.25
# 2020-01-07         68.74
# ...                  ...
# 2024-06-18         84.79
# 2024-06-19         85.64
# 2024-06-20         85.92
# 2024-06-21         86.42
# 2024-06-24         86.75
#
# [1169 rows x 1 columns]

# %%
brent_oil_price = brent_oil_price.dropna()

sns.set_theme()
plt.figure(figsize=(10, 6))
plt.plot(brent_oil_price)
plt.title('Crude Oil Prices: Brent - Europe')
plt.xlabel("Date")
plt.ylabel("Price ($/Barrel)")
plt.show()

# %%
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# import plotly.express as px

# plt.style.use("fivethirtyeight")
# pd.set_option('display.max_rows', 500)
# pd.set_option('display.max_columns', 500)
# pd.set_option('display.width', 1000)
# color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]

# from fredapi import Fred

# fred_API_key = '5065d8cbfcdcd85fcc7c793ac8aafd60'

# #Create a fred object using the API key
# fred = Fred(fred_API_key)

# #search the the FRED system for information on data series
# df = fred.search('DCOILBRENTEU')

# #dowloading time series data from FRED
# spdf = fred.get_series("DCOILBRENTEU")
# spdf = spdf.dropna()

# #Filtering the data for the period more that 1st Jan 2020
# filt = spdf.index > "2020-01-01"
# spdf = spdf[filt]
# #picking the starting reference value for comparision.
# ref_value = spdf.values[0]

# spdf
