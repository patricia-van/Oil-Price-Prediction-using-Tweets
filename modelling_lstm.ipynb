# %%
"""
Data Manipulation and Visualization Libraries
"""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

"""
Datetime Libraries
"""
from datetime import datetime

"""
Modelling Libraries
"""
import joblib
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import adfuller, grangercausalitytests
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.api import VAR, ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import TimeSeriesSplit, cross_validate, cross_val_predict, GridSearchCV

# %%
# set period under observation
start_date = datetime(2022, 7, 1)
end_date = datetime(2024, 5, 31)
# end_date = datetime.today() - relativedelta(months=2)

# %% [markdown]
# ## EDA

# %%
# read crude price data
brent_oil_price = pd.read_csv('Data/DCOILBRENTEU.csv')
brent_oil_price['DATE'] = pd.to_datetime(brent_oil_price['DATE'])
brent_oil_price = brent_oil_price[(brent_oil_price['DATE'] > start_date) & (brent_oil_price['DATE'] < end_date)]

brent_oil_price.columns=['date', 'price']
brent_oil_price.set_index('date', inplace=True)

brent_oil_price.head()
# Out:
#              price
# date
# 2022-07-04  121.80
# 2022-07-05  110.49
# 2022-07-06  108.54
# 2022-07-07  113.40
# 2022-07-08  113.95

# %%
# Plot crude price 
sns.set_theme()
plt.figure(figsize=(15, 6))
plt.plot(brent_oil_price)
plt.title('Crude Oil Prices: Brent - Europe')
plt.xlabel("Date")
plt.ylabel("Price ($/Barrel)")

# Set x-axis to 3-month intervals
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%Y'))

plt.show()

# %%
# read twitter sentiment data 
tweets_sentiment = pd.read_csv('Data/tweets_sentiment.csv', index_col='Unnamed: 0',  lineterminator='\n')

# compute tweet sentiment score and label
tweets_sentiment['sentiment_score'] = tweets_sentiment['Positive'] - tweets_sentiment['Negative']
tweets_sentiment['label'] = tweets_sentiment[['Positive', 'Negative', 'Neutral']].idxmax(axis=1)\
                                .map({'Positive': 1, 'Negative': -1, 'Neutral': 0})

# read twitter topic data 
tweets_topic = pd.read_csv('Data/tweets_topic.csv', index_col='Unnamed: 0')

# merge twitter sentiment and topic into one dataframe
tweets_df = tweets_sentiment.merge(tweets_topic, how='inner', on='id', suffixes=('', '_copy'))
tweets_df.drop(columns=[col for col in tweets_df.columns if col.endswith('_copy')], inplace=True)

# filter for tweets within date range
tweets_df['date'] = pd.to_datetime(tweets_df['date'])
tweets_df = tweets_df[(tweets_df['date'] >= start_date) & (tweets_df['date'] <= end_date)]
tweets_df.tail()
# Out:
#                         id       date lang  \
# 37685  1730343584572867060 2023-11-30   en
# 37686  1730185032914829401 2023-11-30   en
# 37687  1730352191548883361 2023-11-30   en
# 37688  1730348517313466869 2023-11-30   en
# 37689  1730343562728944032 2023-11-30   en
#
#                                               rawContent              user_id  \
# 37685  At least based on today, can't say there's muc...  1209952412338991104
# 37686  Is $XOM's "Death Cross" a reason for #Energy b...  1209952412338991104
# 37687  #OOTT #WTI As the #OPEC+ conspiracy collapsed ...           3066855883
# 37688  #OOTT #WTI [W1]#OPEC+ got clubbed after its pa...           3066855883
# 37689  #OOTT #WTI "For now, the outcome does not live...           3066855883
#
#               username                                   displayname  \
# 37685  TheFortuneTell5         The Fortune Teller @ Wheel of Fortune
# 37686  TheFortuneTell5         The Fortune Teller @ Wheel of Fortune
# 37687           DB_WTI  WTI Trading Group- 🇺🇸 US Crude Oil Trader🛢️🌎
# 37688           DB_WTI  WTI Trading Group- 🇺🇸 US Crude Oil Trader🛢️🌎
# 37689           DB_WTI  WTI Trading Group- 🇺🇸 US Crude Oil Trader🛢️🌎
#
#                                           rawDescription  Positive  Negative  \
# 37685  Market Beast 30+yrs\nInvestment/portfolio mana...  0.044599  0.062963
# 37686  Market Beast 30+yrs\nInvestment/portfolio mana...  0.053212  0.118022
# 37687  💰 The Best Incubator for Future Winning #US #C...  0.311486  0.573089
# 37688  💰 The Best Incubator for Future Winning #US #C...  0.025245  0.888074
# 37689  💰 The Best Incubator for Future Winning #US #C...  0.023566  0.911276
#
#         Neutral  sentiment_score  label  topic
# 37685  0.892437        -0.018364      0      3
# 37686  0.828767        -0.064810      0      3
# 37687  0.115425        -0.261603     -1      0
# 37688  0.086681        -0.862829     -1      0
# 37689  0.065159        -0.887710     -1      0

# %%
# Group tweets by date and calculate average sentiment
daily_sentiment = tweets_df.loc[:, ['date', 'label', 'sentiment_score']]
daily_sentiment = daily_sentiment.groupby(['date']).mean()

daily_sentiment.columns = [f'{col}_0' for col in daily_sentiment.columns]
daily_sentiment.head()
# Out:
#              label_0  sentiment_score_0
# date
# 2022-07-01 -0.180556          -0.133128
# 2022-07-02  0.333333           0.212321
# 2022-07-03 -0.264706          -0.217177
# 2022-07-04 -0.160714          -0.123233
# 2022-07-05 -0.163934          -0.139811

# %%
# Group by date and topic and calculate average sentiment
daily_topic_sentiment = tweets_df.loc[:, ['date', 'label','topic', 'sentiment_score']]
daily_topic_sentiment['topic'] = daily_topic_sentiment['topic']+1
daily_topic_sentiment = daily_topic_sentiment.groupby(['date', 'topic']).mean()

# Unstack 'topic' to become columns
daily_topic_sentiment = daily_topic_sentiment.unstack(level='topic')

# Flatten the column MultiIndex resulting from unstack
daily_topic_sentiment.columns = daily_topic_sentiment.columns.map('{0[0]}_{0[1]}'.format) 

daily_topic_sentiment.head()
# Out:
#              label_1   label_2   label_3   label_4  sentiment_score_1  \
# date
# 2022-07-01 -0.380952  0.000000 -0.263158  0.000000          -0.323286
# 2022-07-02  0.000000  0.000000  1.000000  1.000000          -0.070201
# 2022-07-03 -0.333333 -0.190476 -0.333333 -0.214286          -0.283336
# 2022-07-04 -0.095238 -0.187500 -0.375000 -0.090909          -0.129210
# 2022-07-05 -0.250000 -0.090909  0.000000  0.000000          -0.233597
#
#             sentiment_score_2  sentiment_score_3  sentiment_score_4
# date
# 2022-07-01           0.019052          -0.196079           0.037853
# 2022-07-02          -0.004047           0.648673           0.839905
# 2022-07-03          -0.173141          -0.271328          -0.135003
# 2022-07-04          -0.082532          -0.274846          -0.060758
# 2022-07-05          -0.049497           0.061214          -0.010699

# %%
# merge daily sentiment by topic and overall into one dataframe
daily_sentiment = pd.concat([daily_sentiment, daily_topic_sentiment], axis=1)
daily_sentiment.head()
# Out:
#              label_0  sentiment_score_0   label_1   label_2   label_3  \
# date
# 2022-07-01 -0.180556          -0.133128 -0.380952  0.000000 -0.263158
# 2022-07-02  0.333333           0.212321  0.000000  0.000000  1.000000
# 2022-07-03 -0.264706          -0.217177 -0.333333 -0.190476 -0.333333
# 2022-07-04 -0.160714          -0.123233 -0.095238 -0.187500 -0.375000
# 2022-07-05 -0.163934          -0.139811 -0.250000 -0.090909  0.000000
#
#              label_4  sentiment_score_1  sentiment_score_2  sentiment_score_3  \
# date
# 2022-07-01  0.000000          -0.323286           0.019052          -0.196079
# 2022-07-02  1.000000          -0.070201          -0.004047           0.648673
# 2022-07-03 -0.214286          -0.283336          -0.173141          -0.271328
# 2022-07-04 -0.090909          -0.129210          -0.082532          -0.274846
# 2022-07-05  0.000000          -0.233597          -0.049497           0.061214
#
#             sentiment_score_4
# date
# 2022-07-01           0.037853
# 2022-07-02           0.839905
# 2022-07-03          -0.135003
# 2022-07-04          -0.060758
# 2022-07-05          -0.010699

# %%
# Find percentage of dates without a certain topic
print('% days with no tweets by topic')
print(round(daily_topic_sentiment.isna().sum() * 100 / len(daily_topic_sentiment), 2))
# Out:
# % days with no tweets by topic
# label_1              0.00
# label_2              0.43
# label_3              0.43
# label_4              0.57
# sentiment_score_1    0.00
# sentiment_score_2    0.43
# sentiment_score_3    0.43
# sentiment_score_4    0.57
# dtype: float64

# %%
# Impute empty sentiment scores & labels with 0
features_df = daily_sentiment.fillna(0)

# Compute 7-day rolling average label & sentiment score
features_df = features_df.rolling(window=7).mean()
features_df.tail()
# Out:
#              label_0  sentiment_score_0   label_1   label_2   label_3  \
# date
# 2024-05-27 -0.175591          -0.129427 -0.266826  0.092965 -0.186134
# 2024-05-28 -0.130983          -0.101295 -0.169547  0.140584 -0.200420
# 2024-05-29 -0.094890          -0.076828 -0.118527  0.133163 -0.133193
# 2024-05-30 -0.074111          -0.064200 -0.109173  0.151020 -0.113550
# 2024-05-31 -0.061720          -0.051545 -0.110364  0.133163  0.017402
#
#              label_4  sentiment_score_1  sentiment_score_2  sentiment_score_3  \
# date
# 2024-05-27 -0.123016          -0.250305           0.119174          -0.135923
# 2024-05-28 -0.099206          -0.172202           0.124708          -0.133484
# 2024-05-29 -0.084921          -0.117914           0.102768          -0.082155
# 2024-05-30 -0.016893          -0.115058           0.098831          -0.064777
# 2024-05-31 -0.045465          -0.115020           0.067778           0.065372
#
#             sentiment_score_4
# date
# 2024-05-27          -0.059630
# 2024-05-28          -0.043741
# 2024-05-29          -0.049314
# 2024-05-30           0.002360
# 2024-05-31          -0.001629

# %%
# merge price and features into one dataframe
df = pd.merge(brent_oil_price, features_df, left_index=True, right_index=True)
df.dropna(inplace=True)
df.head()
# Out:
#              price   label_0  sentiment_score_0   label_1   label_2   label_3  \
# date
# 2022-07-07  113.40 -0.092316          -0.086901 -0.188100 -0.120555 -0.011800
# 2022-07-08  113.95 -0.083189          -0.087374 -0.133678 -0.156269  0.001984
# 2022-07-11  114.85 -0.122250          -0.115398 -0.129121 -0.182772 -0.103458
# 2022-07-12  106.98 -0.129643          -0.116865 -0.141026 -0.190193 -0.046315
# 2022-07-13  107.17 -0.113235          -0.104410 -0.123234 -0.148526 -0.046315
#
#              label_4  sentiment_score_1  sentiment_score_2  sentiment_score_3  \
# date
# 2022-07-07  0.083488          -0.190777          -0.078725          -0.002572
# 2022-07-08  0.063080          -0.154155          -0.116261           0.001749
# 2022-07-11 -0.043697          -0.149743          -0.138650          -0.068767
# 2022-07-12 -0.100840          -0.155559          -0.131345          -0.052966
# 2022-07-13 -0.092723          -0.136242          -0.109364          -0.059824
#
#             sentiment_score_4
# date
# 2022-07-07           0.071537
# 2022-07-08           0.053397
# 2022-07-11          -0.043274
# 2022-07-12          -0.074022
# 2022-07-13          -0.067986

# %%
# Create subplots of pruce and sentiment score
fig, axs = plt.subplots(features_df.shape[1], 1, figsize=(14, 20))

# Flatten the axs array for easy iteration
axs = axs.flatten()

# Plot each feature against the target on different y-axes
for i in range(1, df.shape[1]):
    col = df.columns[i]
    ax1 = axs[i-1]
    ax2 = ax1.twinx()
    
    ax1.plot(df['price'], 'k-', label='Price')
    ax2.plot(df[col], 'b-', label=f'Topic {col}')
    
    ax1.set_xlabel('Date')
    ax1.set_ylabel('price', color='black')
    ax2.set_ylabel('Score', color='b')
    
    ax1.tick_params(axis='y', labelcolor='black')
    ax2.tick_params(axis='y', labelcolor='b')
    
    # ax1.legend(loc='upper left')
    # ax2.legend(loc='upper right')
    ax1.set_title(f'Price and Feature={col}')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Stationarity Check

# %%
# Define helper function to check for stationarity
def check_stationarity(df, column, lags, conf_level=0.05):
    # Drop NAs if any
    df = df.dropna(subset=column)

    # Plot acf 
    plot_acf(df[column], lags=lags)
    plt.title(f"Autocorrelation Function (ACF) - {column}")
    plt.xlabel("Lags")
    plt.ylabel("ACF Value")
    plt.show()

    # Compute adf test statistic
    adftest = adfuller(df[column], maxlag=lags, autolag='AIC', regression='ct')
    if adftest[1] < conf_level:
        print("ADF Test Conclusion: Stationary")
    else:
        print("ADF Test Conclusion: Non-stationary")
    print("------------------------------------")
    print("ADF-Statistic:", adftest[0])
    print("P-Value:", adftest[1])
    print("Number of lags:", adftest[2])
    print("Number of observations:", adftest[3])
    print("Critical Values:", adftest[4])
    print(f"Note: If P-Value is smaller than {conf_level}, we reject the null hypothesis and the series is stationary")
    
    return

# %%
check_stationarity(df, 'price', 14)
# Out:
# ADF Test Conclusion: Non-stationary
# ------------------------------------
# ADF-Statistic: -2.9025231993737717
# P-Value: 0.16140059515878052
# Number of lags: 5
# Number of observations: 472
# Critical Values: {'1%': -3.9780791758236447, '5%': -3.419832685881194, '10%': -3.132545796894096}
# Note: If P-Value is smaller than 0.05, we reject the null hypothesis and the series is stationary

# %%
# Calculate crude returns
df['returns'] = df['price'].pct_change(1)
check_stationarity(df, 'returns', 14)
# Out:
# ADF Test Conclusion: Stationary
# ------------------------------------
# ADF-Statistic: -11.01585874133882
# P-Value: 2.0766640062607016e-17
# Number of lags: 4
# Number of observations: 472
# Critical Values: {'1%': -3.9780791758236447, '5%': -3.419832685881194, '10%': -3.132545796894096}
# Note: If P-Value is smaller than 0.05, we reject the null hypothesis and the series is stationary

# %%
for col in features_df.columns:
    check_stationarity(df, col, 14)
# Out:
# ADF Test Conclusion: Stationary
# ------------------------------------
# ADF-Statistic: -4.267521298524593
# P-Value: 0.00353204474213152
# Number of lags: 10
# Number of observations: 467
# Critical Values: {'1%': -3.978287320771828, '5%': -3.419933162931645, '10%': -3.132604833682177}
# Note: If P-Value is smaller than 0.05, we reject the null hypothesis and the series is stationary
# ADF Test Conclusion: Stationary
# ------------------------------------
# ADF-Statistic: -4.498378600068581
# P-Value: 0.0015187627259275307
# Number of lags: 11
# Number of observations: 466
# Critical Values: {'1%': -3.978329489428181, '5%': -3.419953518250008, '10%': -3.1326167935758216}
# Note: If P-Value is smaller than 0.05, we reject the null hypothesis and the series is stationary
# ADF Test Conclusion: Stationary
# ------------------------------------
# ADF-Statistic: -4.498297822554434
# P-Value: 0.0015192246719401585
# Number of lags: 10
# Number of observations: 467
# Critical Values: {'1%': -3.978287320771828, '5%': -3.419933162931645, '10%': -3.132604833682177}
# Note: If P-Value is smaller than 0.05, we reject the null hypothesis and the series is stationary
# ADF Test Conclusion: Stationary
# ------------------------------------
# ADF-Statistic: -4.405743884262903
# P-Value: 0.0021439583981794096
# Number of lags: 10
# Number of observations: 467
# Critical Values: {'1%': -3.978287320771828, '5%': -3.419933162931645, '10%': -3.132604833682177}
# Note: If P-Value is smaller than 0.05, we reject the null hypothesis and the series is stationary
# ADF Test Conclusion: Stationary
# ------------------------------------
# ADF-Statistic: -4.558981374925329
# P-Value: 0.0012068921972590004
# Number of lags: 10
# Number of observations: 467
# Critical Values: {'1%': -3.978287320771828, '5%': -3.419933162931645, '10%': -3.132604833682177}
# Note: If P-Value is smaller than 0.05, we reject the null hypothesis and the series is stationary
# ADF Test Conclusion: Stationary
# ------------------------------------
# ADF-Statistic: -5.434540560288605
# P-Value: 3.10003743866803e-05
# Number of lags: 10
# Number of observations: 467
# Critical Values: {'1%': -3.978287320771828, '5%': -3.419933162931645, '10%': -3.132604833682177}
# Note: If P-Value is smaller than 0.05, we reject the null hypothesis and the series is stationary
# ADF Test Conclusion: Stationary
# ------------------------------------
# ADF-Statistic: -4.3960627786837305
# P-Value: 0.0022215780541333173
# Number of lags: 10
# Number of observations: 467
# Critical Values: {'1%': -3.978287320771828, '5%': -3.419933162931645, '10%': -3.132604833682177}
# Note: If P-Value is smaller than 0.05, we reject the null hypothesis and the series is stationary
# ADF Test Conclusion: Stationary
# ------------------------------------
# ADF-Statistic: -4.694546022462903
# P-Value: 0.0007131386369350023
# Number of lags: 10
# Number of observations: 467
# Critical Values: {'1%': -3.978287320771828, '5%': -3.419933162931645, '10%': -3.132604833682177}
# Note: If P-Value is smaller than 0.05, we reject the null hypothesis and the series is stationary
# ADF Test Conclusion: Stationary
# ------------------------------------
# ADF-Statistic: -4.869958047390243
# P-Value: 0.0003525757834224294
# Number of lags: 10
# Number of observations: 467
# Critical Values: {'1%': -3.978287320771828, '5%': -3.419933162931645, '10%': -3.132604833682177}
# Note: If P-Value is smaller than 0.05, we reject the null hypothesis and the series is stationary
# ADF Test Conclusion: Stationary
# ------------------------------------
# ADF-Statistic: -5.100245227515646
# P-Value: 0.00013460563422018984
# Number of lags: 10
# Number of observations: 467
# Critical Values: {'1%': -3.978287320771828, '5%': -3.419933162931645, '10%': -3.132604833682177}
# Note: If P-Value is smaller than 0.05, we reject the null hypothesis and the series is stationary

# %% [markdown]
# ## Granger Causality Check

# %%
# Define helper function to check for granger causality
def check_granger_causality(df, target, features, maxlag, test='ssr_chi2test', conf_level=0.05):
    # Create dataframe to store confidence p-values
    granger_df = pd.DataFrame()
    granger_df['lag'] = [i for i in range(1,maxlag+1)]
    for feature in features:
        res = grangercausalitytests(df[[target, feature]], maxlag=maxlag)
        p_value = [res.get(i)[0].get(test)[1] for i in res.keys()]
        col_name = f'{feature}_causes_{target}'
        granger_df[col_name] = p_value

    # Plot chart of p-values against lag for each feature and target
    plt.figure(figsize=(16,9))
    for y in granger_df.columns[1:]:   
        plt.plot(granger_df['lag'],granger_df[y],linewidth=3, label=y)
    plt.axhline(conf_level, color='red', linestyle='-.')
    plt.xlabel('lag')
    plt.legend(loc='upper right')
    plt.show()

# %%
model_df = df.dropna()

# check granger causality of returns & sentiment scores
selected_target = 'returns'
selected_features = [col for col in features_df.columns if col.startswith('sentiment_score')]

check_granger_causality(model_df, selected_target, selected_features, 14)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3780  , p=0.2410  , df_denom=473, df_num=1
# ssr based chi2 test:   chi2=1.3867  , p=0.2390  , df=1
# likelihood ratio test: chi2=1.3847  , p=0.2393  , df=1
# parameter F test:         F=1.3780  , p=0.2410  , df_denom=473, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.5957  , p=0.0757  , df_denom=470, df_num=2
# ssr based chi2 test:   chi2=5.2466  , p=0.0726  , df=2
# likelihood ratio test: chi2=5.2178  , p=0.0736  , df=2
# parameter F test:         F=2.5957  , p=0.0757  , df_denom=470, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.7434  , p=0.1573  , df_denom=467, df_num=3
# ssr based chi2 test:   chi2=5.3086  , p=0.1505  , df=3
# likelihood ratio test: chi2=5.2791  , p=0.1525  , df=3
# parameter F test:         F=1.7434  , p=0.1573  , df_denom=467, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.4731  , p=0.2092  , df_denom=464, df_num=4
# ssr based chi2 test:   chi2=6.0066  , p=0.1987  , df=4
# likelihood ratio test: chi2=5.9688  , p=0.2015  , df=4
# parameter F test:         F=1.4731  , p=0.2092  , df_denom=464, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.9807  , p=0.0117  , df_denom=461, df_num=5
# ssr based chi2 test:   chi2=15.2593 , p=0.0093  , df=5
# likelihood ratio test: chi2=15.0178 , p=0.0103  , df=5
# parameter F test:         F=2.9807  , p=0.0117  , df_denom=461, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.5552  , p=0.0192  , df_denom=458, df_num=6
# ssr based chi2 test:   chi2=15.7665 , p=0.0151  , df=6
# likelihood ratio test: chi2=15.5084 , p=0.0167  , df=6
# parameter F test:         F=2.5552  , p=0.0192  , df_denom=458, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.4546  , p=0.0177  , df_denom=455, df_num=7
# ssr based chi2 test:   chi2=17.7490 , p=0.0132  , df=7
# likelihood ratio test: chi2=17.4220 , p=0.0149  , df=7
# parameter F test:         F=2.4546  , p=0.0177  , df_denom=455, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.4634  , p=0.0128  , df_denom=452, df_num=8
# ssr based chi2 test:   chi2=20.4481 , p=0.0088  , df=8
# likelihood ratio test: chi2=20.0149 , p=0.0103  , df=8
# parameter F test:         F=2.4634  , p=0.0128  , df_denom=452, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.2503  , p=0.0181  , df_denom=449, df_num=9
# ssr based chi2 test:   chi2=21.1101 , p=0.0122  , df=9
# likelihood ratio test: chi2=20.6479 , p=0.0143  , df=9
# parameter F test:         F=2.2503  , p=0.0181  , df_denom=449, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.0428  , p=0.0278  , df_denom=446, df_num=10
# ssr based chi2 test:   chi2=21.3900 , p=0.0185  , df=10
# likelihood ratio test: chi2=20.9146 , p=0.0217  , df=10
# parameter F test:         F=2.0428  , p=0.0278  , df_denom=446, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=2.0349  , p=0.0239  , df_denom=443, df_num=11
# ssr based chi2 test:   chi2=23.5460 , p=0.0148  , df=11
# likelihood ratio test: chi2=22.9705 , p=0.0178  , df=11
# parameter F test:         F=2.0349  , p=0.0239  , df_denom=443, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.9160  , p=0.0307  , df_denom=440, df_num=12
# ssr based chi2 test:   chi2=24.2982 , p=0.0185  , df=12
# likelihood ratio test: chi2=23.6846 , p=0.0224  , df=12
# parameter F test:         F=1.9160  , p=0.0307  , df_denom=440, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.6884  , p=0.0605  , df_denom=437, df_num=13
# ssr based chi2 test:   chi2=23.3060 , p=0.0381  , df=13
# likelihood ratio test: chi2=22.7396 , p=0.0449  , df=13
# parameter F test:         F=1.6884  , p=0.0605  , df_denom=437, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.7384  , p=0.0458  , df_denom=434, df_num=14
# ssr based chi2 test:   chi2=25.9633 , p=0.0262  , df=14
# likelihood ratio test: chi2=25.2614 , p=0.0321  , df=14
# parameter F test:         F=1.7384  , p=0.0458  , df_denom=434, df_num=14
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0079  , p=0.9292  , df_denom=473, df_num=1
# ssr based chi2 test:   chi2=0.0080  , p=0.9289  , df=1
# likelihood ratio test: chi2=0.0080  , p=0.9289  , df=1
# parameter F test:         F=0.0079  , p=0.9292  , df_denom=473, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.5882  , p=0.0762  , df_denom=470, df_num=2
# ssr based chi2 test:   chi2=5.2315  , p=0.0731  , df=2
# likelihood ratio test: chi2=5.2029  , p=0.0742  , df=2
# parameter F test:         F=2.5882  , p=0.0762  , df_denom=470, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.1517  , p=0.0930  , df_denom=467, df_num=3
# ssr based chi2 test:   chi2=6.5519  , p=0.0876  , df=3
# likelihood ratio test: chi2=6.5070  , p=0.0894  , df=3
# parameter F test:         F=2.1517  , p=0.0930  , df_denom=467, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.9308  , p=0.1042  , df_denom=464, df_num=4
# ssr based chi2 test:   chi2=7.8730  , p=0.0963  , df=4
# likelihood ratio test: chi2=7.8082  , p=0.0989  , df=4
# parameter F test:         F=1.9308  , p=0.1042  , df_denom=464, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.0033  , p=0.0111  , df_denom=461, df_num=5
# ssr based chi2 test:   chi2=15.3746 , p=0.0089  , df=5
# likelihood ratio test: chi2=15.1295 , p=0.0098  , df=5
# parameter F test:         F=3.0033  , p=0.0111  , df_denom=461, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.4936  , p=0.0220  , df_denom=458, df_num=6
# ssr based chi2 test:   chi2=15.3863 , p=0.0175  , df=6
# likelihood ratio test: chi2=15.1404 , p=0.0192  , df=6
# parameter F test:         F=2.4936  , p=0.0220  , df_denom=458, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.1935  , p=0.0337  , df_denom=455, df_num=7
# ssr based chi2 test:   chi2=15.8605 , p=0.0264  , df=7
# likelihood ratio test: chi2=15.5987 , p=0.0290  , df=7
# parameter F test:         F=2.1935  , p=0.0337  , df_denom=455, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.9840  , p=0.0468  , df_denom=452, df_num=8
# ssr based chi2 test:   chi2=16.4688 , p=0.0361  , df=8
# likelihood ratio test: chi2=16.1863 , p=0.0398  , df=8
# parameter F test:         F=1.9840  , p=0.0468  , df_denom=452, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.7384  , p=0.0781  , df_denom=449, df_num=9
# ssr based chi2 test:   chi2=16.3074 , p=0.0607  , df=9
# likelihood ratio test: chi2=16.0297 , p=0.0663  , df=9
# parameter F test:         F=1.7384  , p=0.0781  , df_denom=449, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.5567  , p=0.1169  , df_denom=446, df_num=10
# ssr based chi2 test:   chi2=16.2998 , p=0.0914  , df=10
# likelihood ratio test: chi2=16.0218 , p=0.0990  , df=10
# parameter F test:         F=1.5567  , p=0.1169  , df_denom=446, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.5076  , p=0.1254  , df_denom=443, df_num=11
# ssr based chi2 test:   chi2=17.4451 , p=0.0954  , df=11
# likelihood ratio test: chi2=17.1265 , p=0.1042  , df=11
# parameter F test:         F=1.5076  , p=0.1254  , df_denom=443, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.4202  , p=0.1530  , df_denom=440, df_num=12
# ssr based chi2 test:   chi2=18.0111 , p=0.1154  , df=12
# likelihood ratio test: chi2=17.6711 , p=0.1260  , df=12
# parameter F test:         F=1.4202  , p=0.1530  , df_denom=440, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.1268  , p=0.3337  , df_denom=437, df_num=13
# ssr based chi2 test:   chi2=15.5536 , p=0.2741  , df=13
# likelihood ratio test: chi2=15.2986 , p=0.2891  , df=13
# parameter F test:         F=1.1268  , p=0.3337  , df_denom=437, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.0741  , p=0.3791  , df_denom=434, df_num=14
# ssr based chi2 test:   chi2=16.0424 , p=0.3108  , df=14
# likelihood ratio test: chi2=15.7707 , p=0.3276  , df=14
# parameter F test:         F=1.0741  , p=0.3791  , df_denom=434, df_num=14
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.5635  , p=0.2118  , df_denom=473, df_num=1
# ssr based chi2 test:   chi2=1.5734  , p=0.2097  , df=1
# likelihood ratio test: chi2=1.5708  , p=0.2101  , df=1
# parameter F test:         F=1.5635  , p=0.2118  , df_denom=473, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8838  , p=0.4139  , df_denom=470, df_num=2
# ssr based chi2 test:   chi2=1.7864  , p=0.4093  , df=2
# likelihood ratio test: chi2=1.7831  , p=0.4100  , df=2
# parameter F test:         F=0.8838  , p=0.4139  , df_denom=470, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7587  , p=0.5177  , df_denom=467, df_num=3
# ssr based chi2 test:   chi2=2.3101  , p=0.5106  , df=3
# likelihood ratio test: chi2=2.3045  , p=0.5117  , df=3
# parameter F test:         F=0.7587  , p=0.5177  , df_denom=467, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5487  , p=0.7000  , df_denom=464, df_num=4
# ssr based chi2 test:   chi2=2.2375  , p=0.6922  , df=4
# likelihood ratio test: chi2=2.2323  , p=0.6931  , df=4
# parameter F test:         F=0.5487  , p=0.7000  , df_denom=464, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0356  , p=0.3960  , df_denom=461, df_num=5
# ssr based chi2 test:   chi2=5.3017  , p=0.3802  , df=5
# likelihood ratio test: chi2=5.2722  , p=0.3836  , df=5
# parameter F test:         F=1.0356  , p=0.3960  , df_denom=461, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0523  , p=0.3906  , df_denom=458, df_num=6
# ssr based chi2 test:   chi2=6.4933  , p=0.3703  , df=6
# likelihood ratio test: chi2=6.4489  , p=0.3748  , df=6
# parameter F test:         F=1.0523  , p=0.3906  , df_denom=458, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.3628  , p=0.2192  , df_denom=455, df_num=7
# ssr based chi2 test:   chi2=9.8538  , p=0.1970  , df=7
# likelihood ratio test: chi2=9.7520  , p=0.2031  , df=7
# parameter F test:         F=1.3628  , p=0.2192  , df_denom=455, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1860  , p=0.3056  , df_denom=452, df_num=8
# ssr based chi2 test:   chi2=9.8449  , p=0.2761  , df=8
# likelihood ratio test: chi2=9.7430  , p=0.2835  , df=8
# parameter F test:         F=1.1860  , p=0.3056  , df_denom=452, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0869  , p=0.3709  , df_denom=449, df_num=9
# ssr based chi2 test:   chi2=10.1960 , p=0.3348  , df=9
# likelihood ratio test: chi2=10.0866 , p=0.3435  , df=9
# parameter F test:         F=1.0869  , p=0.3709  , df_denom=449, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.0194  , p=0.4258  , df_denom=446, df_num=10
# ssr based chi2 test:   chi2=10.6737 , p=0.3835  , df=10
# likelihood ratio test: chi2=10.5536 , p=0.3933  , df=10
# parameter F test:         F=1.0194  , p=0.4258  , df_denom=446, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.0594  , p=0.3929  , df_denom=443, df_num=11
# ssr based chi2 test:   chi2=12.2587 , p=0.3445  , df=11
# likelihood ratio test: chi2=12.1002 , p=0.3562  , df=11
# parameter F test:         F=1.0594  , p=0.3929  , df_denom=443, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.9680  , p=0.4787  , df_denom=440, df_num=12
# ssr based chi2 test:   chi2=12.2766 , p=0.4237  , df=12
# likelihood ratio test: chi2=12.1173 , p=0.4363  , df=12
# parameter F test:         F=0.9680  , p=0.4787  , df_denom=440, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.0923  , p=0.3634  , df_denom=437, df_num=13
# ssr based chi2 test:   chi2=15.0774 , p=0.3025  , df=13
# likelihood ratio test: chi2=14.8377 , p=0.3176  , df=13
# parameter F test:         F=1.0923  , p=0.3634  , df_denom=437, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.1208  , p=0.3367  , df_denom=434, df_num=14
# ssr based chi2 test:   chi2=16.7397 , p=0.2703  , df=14
# likelihood ratio test: chi2=16.4441 , p=0.2870  , df=14
# parameter F test:         F=1.1208  , p=0.3367  , df_denom=434, df_num=14
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5631  , p=0.4534  , df_denom=473, df_num=1
# ssr based chi2 test:   chi2=0.5667  , p=0.4516  , df=1
# likelihood ratio test: chi2=0.5663  , p=0.4517  , df=1
# parameter F test:         F=0.5631  , p=0.4534  , df_denom=473, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3564  , p=0.2586  , df_denom=470, df_num=2
# ssr based chi2 test:   chi2=2.7416  , p=0.2539  , df=2
# likelihood ratio test: chi2=2.7338  , p=0.2549  , df=2
# parameter F test:         F=1.3564  , p=0.2586  , df_denom=470, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8329  , p=0.4763  , df_denom=467, df_num=3
# ssr based chi2 test:   chi2=2.5361  , p=0.4688  , df=3
# likelihood ratio test: chi2=2.5293  , p=0.4700  , df=3
# parameter F test:         F=0.8329  , p=0.4763  , df_denom=467, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0073  , p=0.4032  , df_denom=464, df_num=4
# ssr based chi2 test:   chi2=4.1076  , p=0.3916  , df=4
# likelihood ratio test: chi2=4.0898  , p=0.3940  , df=4
# parameter F test:         F=1.0073  , p=0.4032  , df_denom=464, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.7493  , p=0.1220  , df_denom=461, df_num=5
# ssr based chi2 test:   chi2=8.9552  , p=0.1109  , df=5
# likelihood ratio test: chi2=8.8713  , p=0.1143  , df=5
# parameter F test:         F=1.7493  , p=0.1220  , df_denom=461, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.6211  , p=0.1394  , df_denom=458, df_num=6
# ssr based chi2 test:   chi2=10.0028 , p=0.1245  , df=6
# likelihood ratio test: chi2=9.8980  , p=0.1290  , df=6
# parameter F test:         F=1.6211  , p=0.1394  , df_denom=458, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.3652  , p=0.2181  , df_denom=455, df_num=7
# ssr based chi2 test:   chi2=9.8715  , p=0.1960  , df=7
# likelihood ratio test: chi2=9.7692  , p=0.2020  , df=7
# parameter F test:         F=1.3652  , p=0.2181  , df_denom=455, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3257  , p=0.2283  , df_denom=452, df_num=8
# ssr based chi2 test:   chi2=11.0049 , p=0.2014  , df=8
# likelihood ratio test: chi2=10.8777 , p=0.2087  , df=8
# parameter F test:         F=1.3257  , p=0.2283  , df_denom=452, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.4340  , p=0.1708  , df_denom=449, df_num=9
# ssr based chi2 test:   chi2=13.4523 , p=0.1432  , df=9
# likelihood ratio test: chi2=13.2626 , p=0.1511  , df=9
# parameter F test:         F=1.4340  , p=0.1708  , df_denom=449, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3056  , p=0.2246  , df_denom=446, df_num=10
# ssr based chi2 test:   chi2=13.6704 , p=0.1886  , df=10
# likelihood ratio test: chi2=13.4742 , p=0.1984  , df=10
# parameter F test:         F=1.3056  , p=0.2246  , df_denom=446, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.3763  , p=0.1808  , df_denom=443, df_num=11
# ssr based chi2 test:   chi2=15.9252 , p=0.1439  , df=11
# likelihood ratio test: chi2=15.6591 , p=0.1543  , df=11
# parameter F test:         F=1.3763  , p=0.1808  , df_denom=443, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.3967  , p=0.1639  , df_denom=440, df_num=12
# ssr based chi2 test:   chi2=17.7122 , p=0.1247  , df=12
# likelihood ratio test: chi2=17.3832 , p=0.1357  , df=12
# parameter F test:         F=1.3967  , p=0.1639  , df_denom=440, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.5381  , p=0.1004  , df_denom=437, df_num=13
# ssr based chi2 test:   chi2=21.2313 , p=0.0685  , df=13
# likelihood ratio test: chi2=20.7599 , p=0.0778  , df=13
# parameter F test:         F=1.5381  , p=0.1004  , df_denom=437, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.5774  , p=0.0821  , df_denom=434, df_num=14
# ssr based chi2 test:   chi2=23.5590 , p=0.0518  , df=14
# likelihood ratio test: chi2=22.9792 , p=0.0606  , df=14
# parameter F test:         F=1.5774  , p=0.0821  , df_denom=434, df_num=14
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7334  , p=0.3922  , df_denom=473, df_num=1
# ssr based chi2 test:   chi2=0.7381  , p=0.3903  , df=1
# likelihood ratio test: chi2=0.7375  , p=0.3905  , df=1
# parameter F test:         F=0.7334  , p=0.3922  , df_denom=473, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.4823  , p=0.2282  , df_denom=470, df_num=2
# ssr based chi2 test:   chi2=2.9962  , p=0.2236  , df=2
# likelihood ratio test: chi2=2.9868  , p=0.2246  , df=2
# parameter F test:         F=1.4823  , p=0.2282  , df_denom=470, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7442  , p=0.5261  , df_denom=467, df_num=3
# ssr based chi2 test:   chi2=2.2661  , p=0.5190  , df=3
# likelihood ratio test: chi2=2.2607  , p=0.5201  , df=3
# parameter F test:         F=0.7442  , p=0.5261  , df_denom=467, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6672  , p=0.6150  , df_denom=464, df_num=4
# ssr based chi2 test:   chi2=2.7207  , p=0.6056  , df=4
# likelihood ratio test: chi2=2.7129  , p=0.6070  , df=4
# parameter F test:         F=0.6672  , p=0.6150  , df_denom=464, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4603  , p=0.8058  , df_denom=461, df_num=5
# ssr based chi2 test:   chi2=2.3566  , p=0.7979  , df=5
# likelihood ratio test: chi2=2.3507  , p=0.7988  , df=5
# parameter F test:         F=0.4603  , p=0.8058  , df_denom=461, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3202  , p=0.9264  , df_denom=458, df_num=6
# ssr based chi2 test:   chi2=1.9759  , p=0.9219  , df=6
# likelihood ratio test: chi2=1.9717  , p=0.9223  , df=6
# parameter F test:         F=0.3202  , p=0.9264  , df_denom=458, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.2777  , p=0.9625  , df_denom=455, df_num=7
# ssr based chi2 test:   chi2=2.0079  , p=0.9594  , df=7
# likelihood ratio test: chi2=2.0037  , p=0.9596  , df=7
# parameter F test:         F=0.2777  , p=0.9625  , df_denom=455, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.2584  , p=0.9786  , df_denom=452, df_num=8
# ssr based chi2 test:   chi2=2.1448  , p=0.9762  , df=8
# likelihood ratio test: chi2=2.1399  , p=0.9764  , df=8
# parameter F test:         F=0.2584  , p=0.9786  , df_denom=452, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.4578  , p=0.9024  , df_denom=449, df_num=9
# ssr based chi2 test:   chi2=4.2945  , p=0.8910  , df=9
# likelihood ratio test: chi2=4.2749  , p=0.8924  , df=9
# parameter F test:         F=0.4578  , p=0.9024  , df_denom=449, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.3760  , p=0.9568  , df_denom=446, df_num=10
# ssr based chi2 test:   chi2=3.9371  , p=0.9501  , df=10
# likelihood ratio test: chi2=3.9206  , p=0.9509  , df=10
# parameter F test:         F=0.3760  , p=0.9568  , df_denom=446, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.4078  , p=0.9526  , df_denom=443, df_num=11
# ssr based chi2 test:   chi2=4.7183  , p=0.9440  , df=11
# likelihood ratio test: chi2=4.6945  , p=0.9451  , df=11
# parameter F test:         F=0.4078  , p=0.9526  , df_denom=443, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.4933  , p=0.9187  , df_denom=440, df_num=12
# ssr based chi2 test:   chi2=6.2561  , p=0.9026  , df=12
# likelihood ratio test: chi2=6.2144  , p=0.9049  , df=12
# parameter F test:         F=0.4933  , p=0.9187  , df_denom=440, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=0.4937  , p=0.9282  , df_denom=437, df_num=13
# ssr based chi2 test:   chi2=6.8142  , p=0.9115  , df=13
# likelihood ratio test: chi2=6.7646  , p=0.9139  , df=13
# parameter F test:         F=0.4937  , p=0.9282  , df_denom=437, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.4136  , p=0.9706  , df_denom=434, df_num=14
# ssr based chi2 test:   chi2=6.1772  , p=0.9618  , df=14
# likelihood ratio test: chi2=6.1363  , p=0.9629  , df=14
# parameter F test:         F=0.4136  , p=0.9706  , df_denom=434, df_num=14

# %%
# check granger causality of returns & sentiment labels
selected_target = 'returns'
selected_features = [col for col in features_df.columns if col.startswith('label')]

check_granger_causality(model_df, selected_target, selected_features, 14)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8450  , p=0.3584  , df_denom=473, df_num=1
# ssr based chi2 test:   chi2=0.8504  , p=0.3564  , df=1
# likelihood ratio test: chi2=0.8496  , p=0.3567  , df=1
# parameter F test:         F=0.8450  , p=0.3584  , df_denom=473, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3046  , p=0.1009  , df_denom=470, df_num=2
# ssr based chi2 test:   chi2=4.6583  , p=0.0974  , df=2
# likelihood ratio test: chi2=4.6356  , p=0.0985  , df=2
# parameter F test:         F=2.3046  , p=0.1009  , df_denom=470, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4633  , p=0.2238  , df_denom=467, df_num=3
# ssr based chi2 test:   chi2=4.4558  , p=0.2163  , df=3
# likelihood ratio test: chi2=4.4349  , p=0.2182  , df=3
# parameter F test:         F=1.4633  , p=0.2238  , df_denom=467, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.4447  , p=0.2182  , df_denom=464, df_num=4
# ssr based chi2 test:   chi2=5.8909  , p=0.2074  , df=4
# likelihood ratio test: chi2=5.8545  , p=0.2103  , df=4
# parameter F test:         F=1.4447  , p=0.2182  , df_denom=464, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.8198  , p=0.0160  , df_denom=461, df_num=5
# ssr based chi2 test:   chi2=14.4352 , p=0.0131  , df=5
# likelihood ratio test: chi2=14.2189 , p=0.0143  , df=5
# parameter F test:         F=2.8198  , p=0.0160  , df_denom=461, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.5029  , p=0.0215  , df_denom=458, df_num=6
# ssr based chi2 test:   chi2=15.4439 , p=0.0171  , df=6
# likelihood ratio test: chi2=15.1961 , p=0.0188  , df=6
# parameter F test:         F=2.5029  , p=0.0215  , df_denom=458, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.6921  , p=0.0097  , df_denom=455, df_num=7
# ssr based chi2 test:   chi2=19.4663 , p=0.0068  , df=7
# likelihood ratio test: chi2=19.0740 , p=0.0080  , df=7
# parameter F test:         F=2.6921  , p=0.0097  , df_denom=455, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.5884  , p=0.0090  , df_denom=452, df_num=8
# ssr based chi2 test:   chi2=21.4857 , p=0.0060  , df=8
# likelihood ratio test: chi2=21.0081 , p=0.0071  , df=8
# parameter F test:         F=2.5884  , p=0.0090  , df_denom=452, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.4192  , p=0.0109  , df_denom=449, df_num=9
# ssr based chi2 test:   chi2=22.6944 , p=0.0069  , df=9
# likelihood ratio test: chi2=22.1613 , p=0.0084  , df=9
# parameter F test:         F=2.4192  , p=0.0109  , df_denom=449, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.1997  , p=0.0169  , df_denom=446, df_num=10
# ssr based chi2 test:   chi2=23.0324 , p=0.0106  , df=10
# likelihood ratio test: chi2=22.4824 , p=0.0128  , df=10
# parameter F test:         F=2.1997  , p=0.0169  , df_denom=446, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=2.1605  , p=0.0156  , df_denom=443, df_num=11
# ssr based chi2 test:   chi2=24.9989 , p=0.0091  , df=11
# likelihood ratio test: chi2=24.3514 , p=0.0113  , df=11
# parameter F test:         F=2.1605  , p=0.0156  , df_denom=443, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=2.0438  , p=0.0195  , df_denom=440, df_num=12
# ssr based chi2 test:   chi2=25.9195 , p=0.0110  , df=12
# likelihood ratio test: chi2=25.2229 , p=0.0138  , df=12
# parameter F test:         F=2.0438  , p=0.0195  , df_denom=440, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.7671  , p=0.0458  , df_denom=437, df_num=13
# ssr based chi2 test:   chi2=24.3919 , p=0.0277  , df=13
# likelihood ratio test: chi2=23.7724 , p=0.0333  , df=13
# parameter F test:         F=1.7671  , p=0.0458  , df_denom=437, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.7143  , p=0.0501  , df_denom=434, df_num=14
# ssr based chi2 test:   chi2=25.6045 , p=0.0290  , df=14
# likelihood ratio test: chi2=24.9215 , p=0.0353  , df=14
# parameter F test:         F=1.7143  , p=0.0501  , df_denom=434, df_num=14
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0002  , p=0.9899  , df_denom=473, df_num=1
# ssr based chi2 test:   chi2=0.0002  , p=0.9898  , df=1
# likelihood ratio test: chi2=0.0002  , p=0.9898  , df=1
# parameter F test:         F=0.0002  , p=0.9899  , df_denom=473, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.2864  , p=0.1028  , df_denom=470, df_num=2
# ssr based chi2 test:   chi2=4.6215  , p=0.0992  , df=2
# likelihood ratio test: chi2=4.5992  , p=0.1003  , df=2
# parameter F test:         F=2.2864  , p=0.1028  , df_denom=470, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.9029  , p=0.1283  , df_denom=467, df_num=3
# ssr based chi2 test:   chi2=5.7942  , p=0.1221  , df=3
# likelihood ratio test: chi2=5.7591  , p=0.1239  , df=3
# parameter F test:         F=1.9029  , p=0.1283  , df_denom=467, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8510  , p=0.1180  , df_denom=464, df_num=4
# ssr based chi2 test:   chi2=7.5475  , p=0.1096  , df=4
# likelihood ratio test: chi2=7.4879  , p=0.1122  , df=4
# parameter F test:         F=1.8510  , p=0.1180  , df_denom=464, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.7018  , p=0.0202  , df_denom=461, df_num=5
# ssr based chi2 test:   chi2=13.8314 , p=0.0167  , df=5
# likelihood ratio test: chi2=13.6326 , p=0.0181  , df=5
# parameter F test:         F=2.7018  , p=0.0202  , df_denom=461, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.3107  , p=0.0330  , df_denom=458, df_num=6
# ssr based chi2 test:   chi2=14.2577 , p=0.0269  , df=6
# likelihood ratio test: chi2=14.0461 , p=0.0291  , df=6
# parameter F test:         F=2.3107  , p=0.0330  , df_denom=458, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.0307  , p=0.0499  , df_denom=455, df_num=7
# ssr based chi2 test:   chi2=14.6836 , p=0.0403  , df=7
# likelihood ratio test: chi2=14.4589 , p=0.0436  , df=7
# parameter F test:         F=2.0307  , p=0.0499  , df_denom=455, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.7883  , p=0.0773  , df_denom=452, df_num=8
# ssr based chi2 test:   chi2=14.8444 , p=0.0622  , df=8
# likelihood ratio test: chi2=14.6143 , p=0.0671  , df=8
# parameter F test:         F=1.7883  , p=0.0773  , df_denom=452, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.5771  , p=0.1194  , df_denom=449, df_num=9
# ssr based chi2 test:   chi2=14.7946 , p=0.0967  , df=9
# likelihood ratio test: chi2=14.5656 , p=0.1036  , df=9
# parameter F test:         F=1.5771  , p=0.1194  , df_denom=449, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3897  , p=0.1820  , df_denom=446, df_num=10
# ssr based chi2 test:   chi2=14.5517 , p=0.1493  , df=10
# likelihood ratio test: chi2=14.3296 , p=0.1585  , df=10
# parameter F test:         F=1.3897  , p=0.1820  , df_denom=446, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.3068  , p=0.2174  , df_denom=443, df_num=11
# ssr based chi2 test:   chi2=15.1208 , p=0.1770  , df=11
# likelihood ratio test: chi2=14.8807 , p=0.1880  , df=11
# parameter F test:         F=1.3068  , p=0.2174  , df_denom=443, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.2456  , p=0.2489  , df_denom=440, df_num=12
# ssr based chi2 test:   chi2=15.7964 , p=0.2007  , df=12
# likelihood ratio test: chi2=15.5340 , p=0.2135  , df=12
# parameter F test:         F=1.2456  , p=0.2489  , df_denom=440, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=0.9736  , p=0.4765  , df_denom=437, df_num=13
# ssr based chi2 test:   chi2=13.4389 , p=0.4145  , df=13
# likelihood ratio test: chi2=13.2479 , p=0.4288  , df=13
# parameter F test:         F=0.9736  , p=0.4765  , df_denom=437, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.8936  , p=0.5659  , df_denom=434, df_num=14
# ssr based chi2 test:   chi2=13.3468 , p=0.4994  , df=14
# likelihood ratio test: chi2=13.1581 , p=0.5141  , df=14
# parameter F test:         F=0.8936  , p=0.5659  , df_denom=434, df_num=14
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6679  , p=0.4142  , df_denom=473, df_num=1
# ssr based chi2 test:   chi2=0.6721  , p=0.4123  , df=1
# likelihood ratio test: chi2=0.6716  , p=0.4125  , df=1
# parameter F test:         F=0.6679  , p=0.4142  , df_denom=473, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4142  , p=0.6611  , df_denom=470, df_num=2
# ssr based chi2 test:   chi2=0.8373  , p=0.6579  , df=2
# likelihood ratio test: chi2=0.8365  , p=0.6582  , df=2
# parameter F test:         F=0.4142  , p=0.6611  , df_denom=470, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4027  , p=0.7511  , df_denom=467, df_num=3
# ssr based chi2 test:   chi2=1.2262  , p=0.7467  , df=3
# likelihood ratio test: chi2=1.2246  , p=0.7471  , df=3
# parameter F test:         F=0.4027  , p=0.7511  , df_denom=467, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2972  , p=0.8798  , df_denom=464, df_num=4
# ssr based chi2 test:   chi2=1.2117  , p=0.8762  , df=4
# likelihood ratio test: chi2=1.2101  , p=0.8764  , df=4
# parameter F test:         F=0.2972  , p=0.8798  , df_denom=464, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6950  , p=0.6274  , df_denom=461, df_num=5
# ssr based chi2 test:   chi2=3.5580  , p=0.6146  , df=5
# likelihood ratio test: chi2=3.5446  , p=0.6166  , df=5
# parameter F test:         F=0.6950  , p=0.6274  , df_denom=461, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8301  , p=0.5470  , df_denom=458, df_num=6
# ssr based chi2 test:   chi2=5.1220  , p=0.5283  , df=6
# likelihood ratio test: chi2=5.0943  , p=0.5318  , df=6
# parameter F test:         F=0.8301  , p=0.5470  , df_denom=458, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2234  , p=0.2882  , df_denom=455, df_num=7
# ssr based chi2 test:   chi2=8.8458  , p=0.2639  , df=7
# likelihood ratio test: chi2=8.7636  , p=0.2701  , df=7
# parameter F test:         F=1.2234  , p=0.2882  , df_denom=455, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1212  , p=0.3474  , df_denom=452, df_num=8
# ssr based chi2 test:   chi2=9.3067  , p=0.3171  , df=8
# likelihood ratio test: chi2=9.2156  , p=0.3244  , df=8
# parameter F test:         F=1.1212  , p=0.3474  , df_denom=452, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0073  , p=0.4331  , df_denom=449, df_num=9
# ssr based chi2 test:   chi2=9.4492  , p=0.3969  , df=9
# likelihood ratio test: chi2=9.3551  , p=0.4052  , df=9
# parameter F test:         F=1.0073  , p=0.4331  , df_denom=449, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9448  , p=0.4916  , df_denom=446, df_num=10
# ssr based chi2 test:   chi2=9.8925  , p=0.4500  , df=10
# likelihood ratio test: chi2=9.7891  , p=0.4592  , df=10
# parameter F test:         F=0.9448  , p=0.4916  , df_denom=446, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.0166  , p=0.4304  , df_denom=443, df_num=11
# ssr based chi2 test:   chi2=11.7629 , p=0.3817  , df=11
# likelihood ratio test: chi2=11.6169 , p=0.3931  , df=11
# parameter F test:         F=1.0166  , p=0.4304  , df_denom=443, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.9162  , p=0.5304  , df_denom=440, df_num=12
# ssr based chi2 test:   chi2=11.6196 , p=0.4767  , df=12
# likelihood ratio test: chi2=11.4768 , p=0.4886  , df=12
# parameter F test:         F=0.9162  , p=0.5304  , df_denom=440, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.1157  , p=0.3432  , df_denom=437, df_num=13
# ssr based chi2 test:   chi2=15.3997 , p=0.2831  , df=13
# likelihood ratio test: chi2=15.1497 , p=0.2981  , df=13
# parameter F test:         F=1.1157  , p=0.3432  , df_denom=437, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.1190  , p=0.3383  , df_denom=434, df_num=14
# ssr based chi2 test:   chi2=16.7124 , p=0.2718  , df=14
# likelihood ratio test: chi2=16.4179 , p=0.2885  , df=14
# parameter F test:         F=1.1190  , p=0.3383  , df_denom=434, df_num=14
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3798  , p=0.5380  , df_denom=473, df_num=1
# ssr based chi2 test:   chi2=0.3822  , p=0.5364  , df=1
# likelihood ratio test: chi2=0.3821  , p=0.5365  , df=1
# parameter F test:         F=0.3798  , p=0.5380  , df_denom=473, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9100  , p=0.4032  , df_denom=470, df_num=2
# ssr based chi2 test:   chi2=1.8394  , p=0.3986  , df=2
# likelihood ratio test: chi2=1.8358  , p=0.3993  , df=2
# parameter F test:         F=0.9100  , p=0.4032  , df_denom=470, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5257  , p=0.6648  , df_denom=467, df_num=3
# ssr based chi2 test:   chi2=1.6008  , p=0.6592  , df=3
# likelihood ratio test: chi2=1.5981  , p=0.6598  , df=3
# parameter F test:         F=0.5257  , p=0.6648  , df_denom=467, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6026  , p=0.6609  , df_denom=464, df_num=4
# ssr based chi2 test:   chi2=2.4571  , p=0.6523  , df=4
# likelihood ratio test: chi2=2.4508  , p=0.6535  , df=4
# parameter F test:         F=0.6026  , p=0.6609  , df_denom=464, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.3319  , p=0.2494  , df_denom=461, df_num=5
# ssr based chi2 test:   chi2=6.8185  , p=0.2345  , df=5
# likelihood ratio test: chi2=6.7697  , p=0.2383  , df=5
# parameter F test:         F=1.3319  , p=0.2494  , df_denom=461, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.2552  , p=0.2769  , df_denom=458, df_num=6
# ssr based chi2 test:   chi2=7.7451  , p=0.2574  , df=6
# likelihood ratio test: chi2=7.6821  , p=0.2623  , df=6
# parameter F test:         F=1.2552  , p=0.2769  , df_denom=458, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1183  , p=0.3502  , df_denom=455, df_num=7
# ssr based chi2 test:   chi2=8.0860  , p=0.3251  , df=7
# likelihood ratio test: chi2=8.0173  , p=0.3311  , df=7
# parameter F test:         F=1.1183  , p=0.3502  , df_denom=455, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.0000  , p=0.4352  , df_denom=452, df_num=8
# ssr based chi2 test:   chi2=8.3005  , p=0.4047  , df=8
# likelihood ratio test: chi2=8.2279  , p=0.4115  , df=8
# parameter F test:         F=1.0000  , p=0.4352  , df_denom=452, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2387  , p=0.2691  , df_denom=449, df_num=9
# ssr based chi2 test:   chi2=11.6200 , p=0.2356  , df=9
# likelihood ratio test: chi2=11.4781 , p=0.2444  , df=9
# parameter F test:         F=1.2387  , p=0.2691  , df_denom=449, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1691  , p=0.3096  , df_denom=446, df_num=10
# ssr based chi2 test:   chi2=12.2416 , p=0.2692  , df=10
# likelihood ratio test: chi2=12.0839 , p=0.2795  , df=10
# parameter F test:         F=1.1691  , p=0.3096  , df_denom=446, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.1776  , p=0.3001  , df_denom=443, df_num=11
# ssr based chi2 test:   chi2=13.6267 , p=0.2543  , df=11
# likelihood ratio test: chi2=13.4313 , p=0.2661  , df=11
# parameter F test:         F=1.1776  , p=0.3001  , df_denom=443, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.1274  , p=0.3354  , df_denom=440, df_num=12
# ssr based chi2 test:   chi2=14.2973 , p=0.2821  , df=12
# likelihood ratio test: chi2=14.0819 , p=0.2955  , df=12
# parameter F test:         F=1.1274  , p=0.3354  , df_denom=440, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.3587  , p=0.1761  , df_denom=437, df_num=13
# ssr based chi2 test:   chi2=18.7549 , p=0.1309  , df=13
# likelihood ratio test: chi2=18.3858 , p=0.1434  , df=13
# parameter F test:         F=1.3587  , p=0.1761  , df_denom=437, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.3722  , p=0.1628  , df_denom=434, df_num=14
# ssr based chi2 test:   chi2=20.4945 , p=0.1153  , df=14
# likelihood ratio test: chi2=20.0538 , p=0.1285  , df=14
# parameter F test:         F=1.3722  , p=0.1628  , df_denom=434, df_num=14
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0736  , p=0.7863  , df_denom=473, df_num=1
# ssr based chi2 test:   chi2=0.0740  , p=0.7856  , df=1
# likelihood ratio test: chi2=0.0740  , p=0.7856  , df=1
# parameter F test:         F=0.0736  , p=0.7863  , df_denom=473, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7374  , p=0.4789  , df_denom=470, df_num=2
# ssr based chi2 test:   chi2=1.4904  , p=0.4746  , df=2
# likelihood ratio test: chi2=1.4881  , p=0.4752  , df=2
# parameter F test:         F=0.7374  , p=0.4789  , df_denom=470, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3363  , p=0.7991  , df_denom=467, df_num=3
# ssr based chi2 test:   chi2=1.0239  , p=0.7955  , df=3
# likelihood ratio test: chi2=1.0228  , p=0.7957  , df=3
# parameter F test:         F=0.3363  , p=0.7991  , df_denom=467, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3374  , p=0.8528  , df_denom=464, df_num=4
# ssr based chi2 test:   chi2=1.3756  , p=0.8484  , df=4
# likelihood ratio test: chi2=1.3736  , p=0.8488  , df=4
# parameter F test:         F=0.3374  , p=0.8528  , df_denom=464, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.2409  , p=0.9442  , df_denom=461, df_num=5
# ssr based chi2 test:   chi2=1.2331  , p=0.9417  , df=5
# likelihood ratio test: chi2=1.2315  , p=0.9418  , df=5
# parameter F test:         F=0.2409  , p=0.9442  , df_denom=461, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.1717  , p=0.9843  , df_denom=458, df_num=6
# ssr based chi2 test:   chi2=1.0597  , p=0.9832  , df=6
# likelihood ratio test: chi2=1.0585  , p=0.9833  , df=6
# parameter F test:         F=0.1717  , p=0.9843  , df_denom=458, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.3658  , p=0.9219  , df_denom=455, df_num=7
# ssr based chi2 test:   chi2=2.6453  , p=0.9158  , df=7
# likelihood ratio test: chi2=2.6379  , p=0.9164  , df=7
# parameter F test:         F=0.3658  , p=0.9219  , df_denom=455, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.3086  , p=0.9627  , df_denom=452, df_num=8
# ssr based chi2 test:   chi2=2.5613  , p=0.9588  , df=8
# likelihood ratio test: chi2=2.5543  , p=0.9592  , df=8
# parameter F test:         F=0.3086  , p=0.9627  , df_denom=452, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.3726  , p=0.9480  , df_denom=449, df_num=9
# ssr based chi2 test:   chi2=3.4950  , p=0.9414  , df=9
# likelihood ratio test: chi2=3.4820  , p=0.9421  , df=9
# parameter F test:         F=0.3726  , p=0.9480  , df_denom=449, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.3250  , p=0.9744  , df_denom=446, df_num=10
# ssr based chi2 test:   chi2=3.4032  , p=0.9703  , df=10
# likelihood ratio test: chi2=3.3909  , p=0.9707  , df=10
# parameter F test:         F=0.3250  , p=0.9744  , df_denom=446, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.3912  , p=0.9594  , df_denom=443, df_num=11
# ssr based chi2 test:   chi2=4.5263  , p=0.9519  , df=11
# likelihood ratio test: chi2=4.5044  , p=0.9528  , df=11
# parameter F test:         F=0.3912  , p=0.9594  , df_denom=443, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.6194  , p=0.8262  , df_denom=440, df_num=12
# ssr based chi2 test:   chi2=7.8546  , p=0.7964  , df=12
# likelihood ratio test: chi2=7.7890  , p=0.8014  , df=12
# parameter F test:         F=0.6194  , p=0.8262  , df_denom=440, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=0.6681  , p=0.7947  , df_denom=437, df_num=13
# ssr based chi2 test:   chi2=9.2213  , p=0.7560  , df=13
# likelihood ratio test: chi2=9.1309  , p=0.7630  , df=13
# parameter F test:         F=0.6681  , p=0.7947  , df_denom=437, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.5647  , p=0.8923  , df_denom=434, df_num=14
# ssr based chi2 test:   chi2=8.4342  , p=0.8655  , df=14
# likelihood ratio test: chi2=8.3583  , p=0.8698  , df=14
# parameter F test:         F=0.5647  , p=0.8923  , df_denom=434, df_num=14

# %% [markdown]
# ## Lag Selection

# %%
# keep relevant columns
model_df = df.loc[:, ['returns', 'sentiment_score_0', 'sentiment_score_1']]
model_df.dropna(inplace=True)

VAR_model = VAR(model_df)
maxlag = 7

# for i in range(1,maxlag+1):
#     result = VAR_model.fit(i)
#     print('Lag Order =', i)
#     print('AIC : ', result.aic)
#     print('BIC : ', result.bic)
#     print('FPE : ', result.fpe)
#     print('HQIC: ', result.hqic, '\n')

results = VAR_model.fit(maxlags=7, ic='aic')
results.summary()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 06, Aug, 2024
# Time:                     16:00:32
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                   -23.1373
# Nobs:                     471.000    HQIC:                  -23.4423
# Log likelihood:           3619.28    FPE:                5.41122e-11
# AIC:                     -23.6401    Det(Omega_mle):     4.80585e-11
# --------------------------------------------------------------------
# Results for equation returns
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                       -0.002070         0.002190           -0.945           0.345
# L1.returns                  -0.010477         0.049733           -0.211           0.833
# L1.sentiment_score_0        -0.062632         0.078947           -0.793           0.428
# L1.sentiment_score_1         0.105617         0.046666            2.263           0.024
# L2.returns                  -0.083075         0.049589           -1.675           0.094
# L2.sentiment_score_0        -0.040676         0.105924           -0.384           0.701
# L2.sentiment_score_1        -0.043963         0.061699           -0.713           0.476
# L3.returns                  -0.122829         0.049993           -2.457           0.014
# L3.sentiment_score_0         0.022984         0.105739            0.217           0.828
# L3.sentiment_score_1        -0.037275         0.061155           -0.610           0.542
# L4.returns                  -0.062478         0.049918           -1.252           0.211
# L4.sentiment_score_0         0.133445         0.105976            1.259           0.208
# L4.sentiment_score_1         0.046136         0.061158            0.754           0.451
# L5.returns                  -0.105657         0.049735           -2.124           0.034
# L5.sentiment_score_0        -0.233663         0.105696           -2.211           0.027
# L5.sentiment_score_1         0.044113         0.061236            0.720           0.471
# L6.returns                  -0.073776         0.049077           -1.503           0.133
# L6.sentiment_score_0         0.047615         0.078931            0.603           0.546
# L6.sentiment_score_1        -0.043318         0.045298           -0.956           0.339
# =======================================================================================
#
# Results for equation sentiment_score_0
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                       -0.007483         0.001898           -3.942           0.000
# L1.returns                   0.083152         0.043102            1.929           0.054
# L1.sentiment_score_0         0.914155         0.068421           13.361           0.000
# L1.sentiment_score_1         0.009751         0.040444            0.241           0.809
# L2.returns                   0.062507         0.042977            1.454           0.146
# L2.sentiment_score_0         0.003219         0.091801            0.035           0.972
# L2.sentiment_score_1         0.032552         0.053473            0.609           0.543
# L3.returns                   0.088250         0.043327            2.037           0.042
# L3.sentiment_score_0         0.004485         0.091641            0.049           0.961
# L3.sentiment_score_1        -0.019373         0.053001           -0.366           0.715
# L4.returns                   0.052521         0.043262            1.214           0.225
# L4.sentiment_score_0         0.155109         0.091846            1.689           0.091
# L4.sentiment_score_1        -0.057549         0.053004           -1.086           0.278
# L5.returns                  -0.054665         0.043103           -1.268           0.205
# L5.sentiment_score_0        -0.510192         0.091604           -5.570           0.000
# L5.sentiment_score_1         0.014973         0.053072            0.282           0.778
# L6.returns                  -0.039949         0.042534           -0.939           0.348
# L6.sentiment_score_0         0.295130         0.068407            4.314           0.000
# L6.sentiment_score_1         0.037864         0.039259            0.964           0.335
# =======================================================================================
#
# Results for equation sentiment_score_1
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                       -0.015160         0.003370           -4.499           0.000
# L1.returns                   0.150255         0.076514            1.964           0.050
# L1.sentiment_score_0        -0.117437         0.121458           -0.967           0.334
# L1.sentiment_score_1         0.968684         0.071795           13.492           0.000
# L2.returns                   0.136043         0.076292            1.783           0.075
# L2.sentiment_score_0         0.094271         0.162962            0.578           0.563
# L2.sentiment_score_1        -0.034059         0.094923           -0.359           0.720
# L3.returns                   0.238557         0.076913            3.102           0.002
# L3.sentiment_score_0         0.018108         0.162677            0.111           0.911
# L3.sentiment_score_1        -0.023997         0.094086           -0.255           0.799
# L4.returns                   0.166598         0.076798            2.169           0.030
# L4.sentiment_score_0         0.166853         0.163043            1.023           0.306
# L4.sentiment_score_1         0.017185         0.094090            0.183           0.855
# L5.returns                  -0.133061         0.076516           -1.739           0.082
# L5.sentiment_score_0        -0.065299         0.162612           -0.402           0.688
# L5.sentiment_score_1        -0.408430         0.094211           -4.335           0.000
# L6.returns                   0.001164         0.075504            0.015           0.988
# L6.sentiment_score_0        -0.092624         0.121434           -0.763           0.446
# L6.sentiment_score_1         0.338879         0.069691            4.863           0.000
# =======================================================================================
#
# Correlation matrix of residuals
#                       returns  sentiment_score_0  sentiment_score_1
# returns              1.000000           0.265875           0.372973
# sentiment_score_0    0.265875           1.000000           0.767286
# sentiment_score_1    0.372973           0.767286           1.000000

# %%
# Select the optimal lag order
lag_order_selection = VAR_model.select_order(maxlags=7)
print(lag_order_selection.summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# =================================================
#       AIC         BIC         FPE         HQIC
# -------------------------------------------------
# 0      -20.38      -20.35   1.411e-09      -20.37
# 1      -23.29     -23.19*   7.649e-11      -23.25
# 2      -23.32      -23.13   7.489e-11      -23.24
# 3      -23.36      -23.10   7.159e-11      -23.26
# 4      -23.36      -23.02   7.162e-11      -23.22
# 5      -23.42      -22.99   6.758e-11      -23.25
# 6     -23.64*      -23.14  5.400e-11*     -23.44*
# 7      -23.63      -23.05   5.452e-11      -23.40
# -------------------------------------------------

# %%
# add lagged sentiment scores as features
lags = range(1, 7)  # use up to 6 lags based on AIC

model_df = model_df.assign(**{
                f'{col} (t-{lag})': model_df[col].shift(lag)
                for lag in lags
                for col in model_df.columns[1:]
            })

# %%
# add lagged returns as features
for lag in range(1,5):
    model_df = model_df.assign(**{f'returns (t-{lag})': model_df['returns'].shift(lag)})

model_df.head()
# Out:
#              returns  sentiment_score_0  sentiment_score_1  \
# date
# 2022-07-08  0.004850          -0.087374          -0.154155
# 2022-07-11  0.007898          -0.115398          -0.149743
# 2022-07-12 -0.068524          -0.116865          -0.155559
# 2022-07-13  0.001776          -0.104410          -0.136242
# 2022-07-14  0.005319          -0.117771          -0.140339
#
#             sentiment_score_0 (t-1)  sentiment_score_1 (t-1)  \
# date
# 2022-07-08                      NaN                      NaN
# 2022-07-11                -0.087374                -0.154155
# 2022-07-12                -0.115398                -0.149743
# 2022-07-13                -0.116865                -0.155559
# 2022-07-14                -0.104410                -0.136242
#
#             sentiment_score_0 (t-2)  sentiment_score_1 (t-2)  \
# date
# 2022-07-08                      NaN                      NaN
# 2022-07-11                      NaN                      NaN
# 2022-07-12                -0.087374                -0.154155
# 2022-07-13                -0.115398                -0.149743
# 2022-07-14                -0.116865                -0.155559
#
#             sentiment_score_0 (t-3)  sentiment_score_1 (t-3)  \
# date
# 2022-07-08                      NaN                      NaN
# 2022-07-11                      NaN                      NaN
# 2022-07-12                      NaN                      NaN
# 2022-07-13                -0.087374                -0.154155
# 2022-07-14                -0.115398                -0.149743
#
#             sentiment_score_0 (t-4)  sentiment_score_1 (t-4)  \
# date
# 2022-07-08                      NaN                      NaN
# 2022-07-11                      NaN                      NaN
# 2022-07-12                      NaN                      NaN
# 2022-07-13                      NaN                      NaN
# 2022-07-14                -0.087374                -0.154155
#
#             sentiment_score_0 (t-5)  sentiment_score_1 (t-5)  \
# date
# 2022-07-08                      NaN                      NaN
# 2022-07-11                      NaN                      NaN
# 2022-07-12                      NaN                      NaN
# 2022-07-13                      NaN                      NaN
# 2022-07-14                      NaN                      NaN
#
#             sentiment_score_0 (t-6)  sentiment_score_1 (t-6)  returns (t-1)  \
# date
# 2022-07-08                      NaN                      NaN            NaN
# 2022-07-11                      NaN                      NaN       0.004850
# 2022-07-12                      NaN                      NaN       0.007898
# 2022-07-13                      NaN                      NaN      -0.068524
# 2022-07-14                      NaN                      NaN       0.001776
#
#             returns (t-2)  returns (t-3)  returns (t-4)
# date
# 2022-07-08            NaN            NaN            NaN
# 2022-07-11            NaN            NaN            NaN
# 2022-07-12       0.004850            NaN            NaN
# 2022-07-13       0.007898       0.004850            NaN
# 2022-07-14      -0.068524       0.007898        0.00485

# %% [markdown]
# ## Modelling

# %%
import datetime
import sklearn
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import KernelPCA
import numpy as np
import pandas as pd
import math
import keras
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.optimizers import Adam

tf.random.set_seed(42)

# %%
# Sort data by date
model_df.dropna(inplace=True)
model_df = model_df.sort_values('date')
model_df.head()
# Out:
#              returns  sentiment_score_0  sentiment_score_1  \
# date
# 2022-07-18  0.044629          -0.089530          -0.131489
# 2022-07-19 -0.019698          -0.074361          -0.112220
# 2022-07-20  0.007829          -0.076739          -0.150154
# 2022-07-21 -0.026325          -0.061381          -0.143149
# 2022-07-22 -0.053541          -0.057892          -0.166633
#
#             sentiment_score_0 (t-1)  sentiment_score_1 (t-1)  \
# date
# 2022-07-18                -0.101987                -0.129621
# 2022-07-19                -0.089530                -0.131489
# 2022-07-20                -0.074361                -0.112220
# 2022-07-21                -0.076739                -0.150154
# 2022-07-22                -0.061381                -0.143149
#
#             sentiment_score_0 (t-2)  sentiment_score_1 (t-2)  \
# date
# 2022-07-18                -0.117771                -0.140339
# 2022-07-19                -0.101987                -0.129621
# 2022-07-20                -0.089530                -0.131489
# 2022-07-21                -0.074361                -0.112220
# 2022-07-22                -0.076739                -0.150154
#
#             sentiment_score_0 (t-3)  sentiment_score_1 (t-3)  \
# date
# 2022-07-18                -0.104410                -0.136242
# 2022-07-19                -0.117771                -0.140339
# 2022-07-20                -0.101987                -0.129621
# 2022-07-21                -0.089530                -0.131489
# 2022-07-22                -0.074361                -0.112220
#
#             sentiment_score_0 (t-4)  sentiment_score_1 (t-4)  \
# date
# 2022-07-18                -0.116865                -0.155559
# 2022-07-19                -0.104410                -0.136242
# 2022-07-20                -0.117771                -0.140339
# 2022-07-21                -0.101987                -0.129621
# 2022-07-22                -0.089530                -0.131489
#
#             sentiment_score_0 (t-5)  sentiment_score_1 (t-5)  \
# date
# 2022-07-18                -0.115398                -0.149743
# 2022-07-19                -0.116865                -0.155559
# 2022-07-20                -0.104410                -0.136242
# 2022-07-21                -0.117771                -0.140339
# 2022-07-22                -0.101987                -0.129621
#
#             sentiment_score_0 (t-6)  sentiment_score_1 (t-6)  returns (t-1)  \
# date
# 2022-07-18                -0.087374                -0.154155       0.041953
# 2022-07-19                -0.115398                -0.149743       0.044629
# 2022-07-20                -0.116865                -0.155559      -0.019698
# 2022-07-21                -0.104410                -0.136242       0.007829
# 2022-07-22                -0.117771                -0.140339      -0.026325
#
#             returns (t-2)  returns (t-3)  returns (t-4)
# date
# 2022-07-18       0.005319       0.001776      -0.068524
# 2022-07-19       0.041953       0.005319       0.001776
# 2022-07-20       0.044629       0.041953       0.005319
# 2022-07-21      -0.019698       0.044629       0.041953
# 2022-07-22       0.007829      -0.019698       0.044629

# %%
# Applying feature scaling
df_scaled = model_df.copy()

feature_scaler, target_scaler = MinMaxScaler(feature_range=(0, 1)), MinMaxScaler(feature_range=(0, 1))
df_scaled[['sentiment_score_0', 'sentiment_score_1']] = feature_scaler.fit_transform(model_df[['sentiment_score_0', 'sentiment_score_1']].to_numpy())
df_scaled['returns'] = target_scaler.fit_transform(model_df['returns'].to_numpy().reshape(-1,1))

df_scaled.head()
# Out:
#              returns  sentiment_score_0  sentiment_score_1
# date
# 2022-07-08  0.482343           0.543464           0.398974
# 2022-07-11  0.502380           0.436262           0.410100
# 2022-07-12  0.000000           0.430651           0.395435
# 2022-07-13  0.462135           0.478295           0.444146
# 2022-07-14  0.485423           0.427183           0.433815

# %%
# Single step dataset preparation
def singleStepSampler(df, window):
    X = []
    y = []
    for i in range(0, len(df) - window):
        res = []
        for j in range(0, window):
            r = []
            for col in df.columns:
                r.append(df[col][i + j])
            res.append(r)
        X.append(res)
        y.append(df[['returns']].iloc[i + window].values)
    return np.array(X), np.array(y)

# %%
# Dataset splitting
SPLIT = 0.70
(X, y) = singleStepSampler(model_df, 7)
X_train = X[:int(SPLIT * len(X))]
y_train = y[:int(SPLIT * len(y))]
X_test = X[int(SPLIT * len(X)):]
y_test = y[int(SPLIT * len(y)):]
# Out:
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# ...
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])
# /var/folders/vs/w5gtl8px5sxd5ywdly3_3yxh0000gn/T/ipykernel_7953/4185502039.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r.append(df[col][i + j])

# %%
# # Sort data by date
# model_df.dropna(inplace=True)
# model_df = model_df.sort_values('date')

# # Split the data into train and test
# train_set, test_set= np.split(model_df, [int(.67 *len(model_df))])
# X_train, y_train = train_set.iloc[:, 1:], train_set.iloc[:, 0] 
# X_test, y_test = test_set.iloc[:, 1:], test_set.iloc[:, 0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
def madl(y_true, y_pred):
    # y_true, y_pred = y_true.numpy(), y_pred.numpy()
    pointwise_lost = -1 * tf.sign(y_true * y_pred) * tf.abs(y_true)
    return tf.reduce_mean(pointwise_lost)

# %%
lstm = keras.Sequential()
lstm.add(keras.layers.LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
# lstm.add(keras.layers.Dropout(0.2))
lstm.add(keras.layers.LSTM(50))
lstm.add(keras.layers.Dense(1))
optimiser = Adam(learning_rate=0.001)
# lstm.compile(loss = madl, optimizer=optimiser)
lstm.compile(loss = 'mean_squared_error', optimizer=optimiser)
# lstm.summary()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
lstm_madl = keras.Sequential()
lstm_madl.add(keras.layers.LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
# lstm.add(keras.layers.Dropout(0.2))
lstm_madl.add(keras.layers.LSTM(50))
lstm_madl.add(keras.layers.Dense(1))
optimiser = Adam(learning_rate=0.001)
# lstm.compile(loss = madl, optimizer=optimiser)
lstm_madl.compile(loss = madl, optimizer=optimiser)
# lstm_madl.summary()

# %%
history = lstm.fit(X_train, y_train, epochs=30, batch_size=8)
history_madl = lstm_madl.fit(X_train, y_train, epochs=30, batch_size=8)
# Out:
# Epoch 1/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.5349e-04
# Epoch 2/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9361e-04
# Epoch 3/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5122e-04
# Epoch 4/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5779e-04
# Epoch 5/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5738e-04
# Epoch 6/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4682e-04
# Epoch 7/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3440e-04
# Epoch 8/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2913e-04
# Epoch 9/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2574e-04
# Epoch 10/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2265e-04
# Epoch 11/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2001e-04
# Epoch 12/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1763e-04
# Epoch 13/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1552e-04
# Epoch 14/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1357e-04
# Epoch 15/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1180e-04
# Epoch 16/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1011e-04
# Epoch 17/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0856e-04
# Epoch 18/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0704e-04
# Epoch 19/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0563e-04
# Epoch 20/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0417e-04
# Epoch 21/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0290e-04
# Epoch 22/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0146e-04
# Epoch 23/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0137e-04
# Epoch 24/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0452e-04
# Epoch 25/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1913e-04
# Epoch 26/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1707e-04
# Epoch 27/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1254e-04
# Epoch 28/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9838e-04
# Epoch 29/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0134e-04
# Epoch 30/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0522e-04
# Epoch 1/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0017
# Epoch 2/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 3/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 4/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 5/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 6/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 7/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 8/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 9/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 10/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 11/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 12/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 13/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 14/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 15/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 16/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 17/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 18/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 19/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 20/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017
# Epoch 21/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 22/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 23/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 24/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 25/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 26/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 27/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 28/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 29/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 30/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017

# %%
def evaluate_model(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    return mse, mae, r2

# %%
# # Reload the data with the date index
# dataFrame = pd.read_csv('/content/final_data_adj.csv')  # Assuming the CSV file contains a 'Date' column
# dataFrame['Date'] = pd.to_datetime(dataFrame['Date'])
# dataFrame.set_index('Date', inplace=True)
 
# Forecast Plot with Dates on X-axis
y_pred_mse = lstm.predict(X_test)
y_pred_madl = lstm_madl.predict(X_test)
d = {
    'Predicted_Returns (Loss=MSE)': y_pred_mse.reshape(-1),
    'Predicted_Returns (Loss=MADL)': y_pred_madl.reshape(-1),
    'Actual_Returns': y_test.reshape(-1)
}
 
d = pd.DataFrame(d)
d.index = model_df.index[-len(y_test):]  # Assigning the correct date index
d.head()
fig, ax = plt.subplots(figsize=(10, 6))
#  highlight the  forecast
highlight_start = int(len(d) * 0.9)  
highlight_end = len(d) - 1  # Adjusted to stay within bounds


mse, mae, r2 = evaluate_model(y_test.reshape(-1), y_pred_mse.reshape(-1),)
print('LSTM (Loss = MSE)')
print(f"MSE: {mse:.4f}, MAE: {mae:.4f}, R2: {r2:.4f}, MADL: {madl(y_test, y_pred_mse).numpy():.4f}")

mse, mae, r2 = evaluate_model(y_test.reshape(-1), y_pred_madl.reshape(-1),)
print('LSTM (Loss = MADL)')
print(f"MSE: {mse:.4f}, MAE: {mae:.4f}, R2: {r2:.4f}, MADL: {madl(y_test, y_pred_madl).numpy():.4f}")


# Plot the actual values
plt.plot(d['Actual_Returns'][:highlight_start], label=['Actual_Returns'])
 
# Plot predicted values with a dashed line
plt.plot(d['Predicted_Returns (Loss=MSE)'], label=['Predicted_Returns (Loss=MSE)'], linestyle='--', color='grey')
plt.plot(d['Predicted_Returns (Loss=MADL)'], label=['Predicted_Returns (Loss=MADL)'], linestyle='--', color='red')
 
# Highlight the forecasted portion with a different color
plt.axvspan(d.index[highlight_start], d.index[highlight_end], facecolor='lightgreen', alpha=0.5, label='Forecast')
 
plt.title('Multivariate Time-Series forecasting using LSTM')
plt.xlabel('Dates')
plt.ylabel('Values')
ax.legend()
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# LSTM (Loss = MSE)
# MSE: 0.0003, MAE: 0.0136, R2: -0.1247, MADL: -0.0000
# LSTM (Loss = MADL)
# MSE: 0.0003, MAE: 0.0137, R2: -0.0561, MADL: -0.0013

# %%
# save models
joblib.dump(lstm, "models/lstm.joblib")
joblib.dump(lstm_madl, 'models/lstm_madl.joblib')
# Out:
# ['models/lstm_madl.joblib']
